# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/python/blob/main/part1_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# chatper 8. 솔직히 행렬곱은 유용합니다.
# 행렬은 이 모든 복잡한 계산을 매우 간단한 형태로 압축해서 표현할 수 있도록 도와줍니다.
# 대부분의 컴퓨터 프로그래밍 언어는 행렬 작업을 잘 처리하므로 이런 복잡한 업무를 행렬 기반으로 잘 만들어서 컴퓨터에게 넘기기만 하면
# 컴퓨터가 알아서 이를 매우 빠르고 효율적으로 처리할 수 있게 됩니다.

# %%
import numpy as np
a_matrix=np.matrix([[23, 43, 22],[43,12,54]])
print('2행 3열 행렬:\n',a_matrix)
# Out:
# 2행 3열 행렬:
#  [[23 43 22]
#  [43 12 54]]

# %% [markdown]
# **chapter 9. 3계층 신경망에 행렬곱 적용하기**

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![3.jpg](data:image/jpeg;base64,...)
