# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/python/blob/main/p_147_p_149.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **chapter 5. 오차역전파**

# %%
# 이번 장에서는 가중치 매개변수의 기울기를 효율적으로 계산하는 오차 역전파법을 배워보겠습니다.
# back propgation

# 계산 그래프: computational graph
# 계산 과정을 그래프로 나타낸 것.

# %% [markdown]
# ![img.png](data:image/png;base64,...)

# %%
# 문제 1: 현빈 군은 슈퍼에서 1개에 100원인 사과를 2개 샀습니다.
# 이때 지불 금액을 구하세요. 단, 소비세가 10% 부과됩니다.

# 계산 그래프는 계산 과정을 노드와 화살표로 표현합니다.
# 노드는 원으로 표기하고, 원 안에 연산 내용을 적습니다.
# 계산 결과를 화살표 위에 적어 각 노드의 계산 결과가 왼쪽에서 오른쪽으로 전해지게 합니다.

# %% [markdown]
# ![스크린샷 2024-09-03 181616.png](data:image/png;base64,...)

# %%
# 문제 2: 현빈 군은 슈퍼엥서 사과를 2개, 귤을 3개 샀습니다.
# 사과는 1개에 100원, 귤은 1개 150원입니다. 소비세가 10%일 때 지불 금액을 구하세요.
