# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/python/blob/main/perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **URL: https://www.youtube.com/watch?v=YODTXF9OIiw**

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
def step_function(x):
  if x< thres: #theta: 역치
    return 0
  else:
      return 1
# step function

# %%
def gen_training_data(data_point):
  x1=np.random.random(data_point)
  x2=np.random.random(data_point)
  y=(x1+x2>1).astype(int)
  training_set=[((x1[i],x2[i]),y[i]) for i in range(len(x1))]
  #1보다 크면 비가 올 확률이 높고, 1보다 작으면 맑은 날씨
  return training_set

# %%
thres=0.5
w=np.array([0.3,0.5])
lr=0.1

data_point=100
epoch=10
training_set=gen_training_data(data_point)

# %%
training_set[0:5]
# Out:
# [((0.957859745389928, 0.3527512793481944), 1),
#  ((0.07867853146135084, 0.9112997677939588), 0),
#  ((0.7050273669319354, 0.8116641264512302), 1),
#  ((0.1669652488313138, 0.6458969085866203), 0),
#  ((0.5621970256807947, 0.10729201363075713), 0)]

# %%
plt.figure(0)
plt.ylim(-0.1,1.1)
plt.xlim(-0.1,1.1)
ax=plt.gca()
ax.set_aspect('equal',adjustable='box')
for x,y in training_set:
  if y == 1:
    plt.plot(x[0], x[1], 'bo')
  else:
    plt.plot(x[0],x[1], 'go')
plt.show()

# %%
# %matplotlib inline
from time import sleep

plt.figure(0)
plt.ylim(-0.1,1.1)
plt.xlim(-0.1,1.1)
ax=plt.gca()
ax.set_aspect('equal',adjustable='box')

xx=np.linspace(0,1,50)
for i in range(epoch):
  cnt=0
  for x,y in training_set:
    clear_output(wait=True)
    u=sum(x*w)
    error = y - step_function(u)

    for index, value in enumerate(x):
      w[index]=w[index]+lr*error*value

    for xs, ys in training_set[0:cnt]:
      plt.ylim(-0.1,1.1)
      plt.xlim(-0.1,1.1)
      ax=plt.gca()
      ax.set_aspect('equal',adjustable='box')

      if ys == 1:
        plt.plot(xs[0], xs[1], 'bo')
      else:
        plt.plot(xs[0],xs[1],'go')

    yy=-w[1]/w[0]*xx+thres/w[0]

    plt.plot(xx,yy)
    plt.show()
    cnt=cnt+1
    sleep(0.01)
# w[0]*yy+w[1]*xx=thres

# %% [markdown]
# ![스크린샷 2024-08-23 123418.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2024-08-23 123616.png](data:image/png;base64,...)

# %%
w[1] # 거의 0.5에 가까워진다.
# Out:
# 0.46219950999626624

# %%
w[0] # 거의 0.5에 가까워진다.
# Out:
# 0.5456391474004311

# %%
thres # 역치의 값과 가까워진다.
# 따라서 그래프 내에 그래프의 경우, y=-x+1의 꼴로 결과값이 도출된다.
# Out:
# 0.5
