# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/python/blob/main/part1_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# chapter 14. 가중치의 진짜 업데이트
# 여러가지 오차함수
# 신경망에서는 수많은 가중치라는 매개변수를 가지는 복잡하고 어려운 함수에 의해 그 결과 값을 얻습니다.
# 필요한 것은 오차함수(error function)를 올바르게 선택하는 일입니다.

# %% [markdown]
# **오차함수: (목표값-실제값)^2**

# %%
# 제곱 오차 방식이 절대값 방식보다 선호되며 많이 사용되는 이유
# 1. 오차 함수로 제곱오차 방식을 사용하면 경사 하강법의 기울기를 구하는 대수학이 간단해집니다.
# 2. 오차함수가 부드럽고 연속적이므로, 경사 하강법이 잘 동작하게 됩니다. 값이 갑자기 상승하거나 빈 틈이 존재하지 않게 됩니다.
# 3. 최저점에 접근함에 따라 경사가 점점 작아지므로, 목표물을 오버슈팅할 가능성이 작아집니다.

# %% [markdown]
# **미분으로 오차함수 구하기**

# %%
# 미분: 어떤 하나의 변화가 다른 것의 변화에 어떤 영향을 주는 지를 구하는 수학적 접근 방법.
# 학습 데이터를 이용해 학습을 진행할때마다 이를 이용해 가중치를 업데이트해나갈 수 있게 된 것입니다.

# URL: https://ffighting.net/deep-learning-basic/%EB%94%A5%EB%9F%AC%EB%8B%9D-%EC%9D%B4%EC%95%BC%EA%B8%B0/%EC%97%AD%EC%A0%84%ED%8C%8C-%EA%B2%BD%EC%82%AC%ED%95%98%EA%B0%95%EB%B2%95/#google_vignette

# %% [markdown]
# ![img.png](data:image/png;base64,...)

# %% [markdown]
# **학습률**

# %%
# 가중치는 기울이와 반대 방향으로 진행된다.
# 학습률 인자를 적용함으로써 변화의 정도 조정. 학습률은 문제에 따라 조금씩 다르게 튜닝해야 합니다.
# 업데이트 된 새로운 가중치: 방금 구한 오차 기울기에 상수를 곱한 값을 원래 가중치에서 빼줌으로써 구할 수 있다.
#####

# URL: https://velog.io/@gooook/DL-%EC%9D%B8%EA%B3%B5%EC%8B%A0%EA%B2%BD%EB%A7%9D-%ED%95%99%EC%8A%B5

# %% [markdown]
# ![images_gooook_post_bb987d6d-69c2-4730-843c-9506507c2c0a_ic91umJ.png](data:image/png;base64,...)

# %%
# chapter 15. 가중치 업데이트 예제
# 아주 작은 변화에 불과하지만, 수백 또는 수천번 반복하면 가중치는 결국 최적의 값으로 수렴하게 될 것이며,
# 이렇게 학습된 신경망은 학습 데이터들을 잘 반영하는 결과값을 만들어낼 수 있게 될 것이다.
